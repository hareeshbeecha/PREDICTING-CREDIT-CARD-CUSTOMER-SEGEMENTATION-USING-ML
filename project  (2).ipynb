# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('creditcard_dataset.csv')
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 0      768805383  Existing Customer            45      M     High School
# 1      818770008  Existing Customer            49      F        Graduate
# 2      713982108  Existing Customer            51      M        Graduate
# 3      769911858  Existing Customer            40      F     High School
# 4      709106358  Existing Customer            40      M      Uneducated
# ...          ...                ...           ...    ...             ...
# 10122  772366833  Existing Customer            50      M        Graduate
# 10123  710638233  Attrited Customer            41      M         Unknown
# 10124  716506083  Attrited Customer            44      F     High School
# 10125  717406983  Attrited Customer            30      M        Graduate
# 10126  714337233  Attrited Customer            43      F        Graduate
#
#       Marital_Status Income_Category Card_Category  Months_on_book  \
# ...

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 0  768805383  Existing Customer            45      M     High School
# 1  818770008  Existing Customer            49      F        Graduate
# 2  713982108  Existing Customer            51      M        Graduate
# 3  769911858  Existing Customer            40      F     High School
# 4  709106358  Existing Customer            40      M      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Credit_Limit  \
# 0                         5                       1       12691.0
# ...

# %%
df.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 10122  772366833  Existing Customer            50      M        Graduate
# 10123  710638233  Attrited Customer            41      M         Unknown
# 10124  716506083  Attrited Customer            44      F     High School
# 10125  717406983  Attrited Customer            30      M        Graduate
# 10126  714337233  Attrited Customer            43      F        Graduate
#
#       Marital_Status Income_Category Card_Category  Months_on_book  \
# 10122         Single     $40K - $60K          Blue              40
# 10123       Divorced     $40K - $60K          Blue              25
# 10124        Married  Less than $40K          Blue              36
# 10125        Unknown     $40K - $60K          Blue              36
# 10126        Married  Less than $40K        Silver              25
#
#        Total_Relationship_Count  Months_Inactive_12_mon  Credit_Limit  \
# ...

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy',
#        'Total_Trans_Amt', 'Total_Trans_Ct', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
df.shape
# Out:
# (10127, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Education_Level           10127 non-null  object
#  5   Marital_Status            10127 non-null  object
#  6   Income_Category           10127 non-null  object
#  7   Card_Category             10127 non-null  object
#  8   Months_on_book            10127 non-null  int64
#  9   Total_Relationship_Count  10127 non-null  int64
#  10  Months_Inactive_12_mon    10127 non-null  int64
#  11  Credit_Limit              10127 non-null  float64
#  12  Total_Revolving_Bal       10127 non-null  int64
# ...

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Months_on_book  Total_Relationship_Count  \
# count  1.012700e+04  10127.000000    10127.000000              10127.000000
# mean   7.391776e+08     46.325960       35.928409                  3.812580
# std    3.690378e+07      8.016814        7.986416                  1.554408
# min    7.080821e+08     26.000000       13.000000                  1.000000
# 25%    7.130368e+08     41.000000       31.000000                  3.000000
# 50%    7.179264e+08     46.000000       36.000000                  4.000000
# 75%    7.731435e+08     52.000000       40.000000                  5.000000
# max    8.283431e+08     73.000000       56.000000                  6.000000
#
#        Months_Inactive_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count            10127.000000  10127.000000         10127.000000
# mean                 2.341167   8631.953698          1162.814061
# std                  1.010622   9088.776650           814.987335
# ...

# %% [markdown]
# ## Filtering

# %%
df['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
df['Marital_Status'].value_counts()
# Out:
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64

# %%
# TO count the number of females and males
df['Gender'].value_counts()
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64

# %% [markdown]
# ## Checking null values

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# ## Grouping

# %% [markdown]
# #### Calculating the average customer age for each gender

# %%
df.groupby('Gender')['Customer_Age'].mean()
# Out:
# Gender
# F    46.456887
# M    46.178863
# Name: Customer_Age, dtype: float64

# %% [markdown]
# #### Calculating the total transaction amount for each income category

# %%
df.groupby('Income_Category')['Total_Trans_Amt'].sum()
# Out:
# Income_Category
# $120K +            3292923
# $40K - $60K        7886058
# $60K - $80K        6239899
# $80K - $120K       6881344
# Less than $40K    15538139
# Unknown            4761819
# Name: Total_Trans_Amt, dtype: int64

# %% [markdown]
#  #### Grouping by Gender: Average Credit Limit and Total Transaction Amount

# %%
gender_group = df.groupby('Gender').agg({'Credit_Limit': 'mean', 'Total_Trans_Amt': 'sum'}).reset_index()
print("Grouping by Gender - Average Credit Limit and Total Transaction Amount:")
print(gender_group)
# Out:
# Grouping by Gender - Average Credit Limit and Total Transaction Amount:
#   Gender  Credit_Limit  Total_Trans_Amt
# 0      F   5023.854274         23169697
# 1      M  12685.674963         21430485

# %% [markdown]
# ## Sorting

# %% [markdown]
# #### Printing the highest Credit Limit record.

# %%
df_desc_crelim = df.sort_values(by='Credit_Limit', ascending=False)
df_desc_crelim.head(2)
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 7032  715130808  Existing Customer            45      M        Graduate
# 6411  817607358  Attrited Customer            44      F     High School
#
#      Marital_Status Income_Category Card_Category  Months_on_book  \
# 7032         Single     $60K - $80K        Silver              34
# 6411        Unknown         Unknown          Gold              35
#
#       Total_Relationship_Count  Months_Inactive_12_mon  Credit_Limit  \
# 7032                         5                       1       34516.0
# 6411                         3                       3       34516.0
#
#       Total_Revolving_Bal  Avg_Open_To_Buy  Total_Trans_Amt  Total_Trans_Ct  \
# 7032                 1664          32852.0             4912              80
# 6411                    0          34516.0             2227              44
#
#       Avg_Utilization_Ratio
# 7032                  0.048
# 6411                  0.000

# %% [markdown]
# #### Printing the highest Total Transaction amount record

# %%
df_desc_trans_amt = df.sort_values(by='Total_Trans_Amt', ascending=False)
df_desc_trans_amt.head(2)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 9964   718140783  Existing Customer            47      M         Unknown
# 10073  717642633  Existing Customer            51      M        Graduate
#
#       Marital_Status Income_Category Card_Category  Months_on_book  \
# 9964         Married     $60K - $80K          Blue              36
# 10073        Married     $60K - $80K          Blue              40
#
#        Total_Relationship_Count  Months_Inactive_12_mon  Credit_Limit  \
# 9964                          4                       5       10585.0
# 10073                         3                       3        3750.0
#
#        Total_Revolving_Bal  Avg_Open_To_Buy  Total_Trans_Amt  Total_Trans_Ct  \
# 9964                  1749           8836.0            18484             108
# 10073                 1801           1949.0            17995             116
#
#        Avg_Utilization_Ratio
# 9964                   0.165
# 10073                  0.480

# %% [markdown]
# #### Sorting by Customer Age in Ascending Order

# %%
sorted_by_age_asc = df.sort_values(by='Customer_Age', ascending=True)
print("Sorting by Customer Age in Ascending Order:")
print(sorted_by_age_asc.head())
# Out:
# Sorting by Customer Age in Ascending Order:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 910   809342208  Existing Customer            26      M        Graduate
# 1462  771556308  Existing Customer            26      F     High School
# 1592  714248733  Existing Customer            26      F         Unknown
# 5462  711336033  Existing Customer            26      F         Unknown
# 1908  710934033  Existing Customer            26      M     High School
#
#      Marital_Status Income_Category Card_Category  Months_on_book  \
# 910          Single         Unknown          Blue              19
# 1462         Single  Less than $40K          Blue              13
# 1592         Single         Unknown          Blue              13
# 5462         Single         Unknown          Blue              36
# 1908         Single  Less than $40K          Blue              13
#
#       Total_Relationship_Count  Months_Inactive_12_mon  Credit_Limit  \
# ...

# %% [markdown]
# #### Sorting by Credit Limit in Ascending Order

# %%
sorted_by_credit_limit_asc = df.sort_values(by='Credit_Limit', ascending=True)
print("Sorting by Credit Limit in Ascending Order:")
print(sorted_by_credit_limit_asc.head())
# Out:
# Sorting by Credit Limit in Ascending Order:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender Education_Level  \
# 6934  713995233  Existing Customer            38      F     High School
# 419   753606108  Existing Customer            56      M         Unknown
# 4650  712864683  Attrited Customer            42      F       Doctorate
# 6859  711671058  Attrited Customer            48      F      Uneducated
# 6857  708545058  Existing Customer            45      F        Graduate
#
#      Marital_Status Income_Category Card_Category  Months_on_book  \
# 6934        Married  Less than $40K          Blue              36
# 419          Single     $60K - $80K          Blue              49
# 4650         Single  Less than $40K          Blue              30
# 6859        Married         Unknown          Blue              38
# 6857         Single     $40K - $60K          Blue              36
#
#       Total_Relationship_Count  Months_Inactive_12_mon  Credit_Limit  \
# ...

# %% [markdown]
# ### Aggregations

# %%
df.min()
# Out:
# CLIENTNUM                           708082083
# Attrition_Flag              Attrited Customer
# Customer_Age                               26
# Gender                                      F
# Education_Level                       College
# Marital_Status                       Divorced
# Income_Category                       $120K +
# Card_Category                            Blue
# Months_on_book                             13
# Total_Relationship_Count                    1
# Months_Inactive_12_mon                      0
# Credit_Limit                           1438.3
# Total_Revolving_Bal                         0
# Avg_Open_To_Buy                           3.0
# Total_Trans_Amt                           510
# Total_Trans_Ct                             10
# Avg_Utilization_Ratio                     0.0
# dtype: object

# %%
df.max()
# Out:
# CLIENTNUM                           828343083
# Attrition_Flag              Existing Customer
# Customer_Age                               73
# Gender                                      M
# Education_Level                       Unknown
# Marital_Status                        Unknown
# Income_Category                       Unknown
# Card_Category                          Silver
# Months_on_book                             56
# Total_Relationship_Count                    6
# Months_Inactive_12_mon                      6
# Credit_Limit                          34516.0
# Total_Revolving_Bal                      2517
# Avg_Open_To_Buy                       34516.0
# Total_Trans_Amt                         18484
# Total_Trans_Ct                            139
# Avg_Utilization_Ratio                   0.999
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\haasi\AppData\Local\Temp\ipykernel_19808\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# CLIENTNUM                   7.391776e+08
# Customer_Age                4.632596e+01
# Months_on_book              3.592841e+01
# Total_Relationship_Count    3.812580e+00
# Months_Inactive_12_mon      2.341167e+00
# Credit_Limit                8.631954e+03
# Total_Revolving_Bal         1.162814e+03
# Avg_Open_To_Buy             7.469140e+03
# Total_Trans_Amt             4.404086e+03
# Total_Trans_Ct              6.485869e+01
# Avg_Utilization_Ratio       2.748936e-01
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\haasi\AppData\Local\Temp\ipykernel_19808\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# CLIENTNUM                   3.690378e+07
# Customer_Age                8.016814e+00
# Months_on_book              7.986416e+00
# Total_Relationship_Count    1.554408e+00
# Months_Inactive_12_mon      1.010622e+00
# Credit_Limit                9.088777e+03
# Total_Revolving_Bal         8.149873e+02
# Avg_Open_To_Buy             9.090685e+03
# Total_Trans_Amt             3.397129e+03
# Total_Trans_Ct              2.347257e+01
# Avg_Utilization_Ratio       2.756915e-01
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\haasi\AppData\Local\Temp\ipykernel_19808\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# CLIENTNUM                   1.361889e+15
# Customer_Age                6.426931e+01
# Months_on_book              6.378285e+01
# Total_Relationship_Count    2.416184e+00
# Months_Inactive_12_mon      1.021358e+00
# Credit_Limit                8.260586e+07
# Total_Revolving_Bal         6.642044e+05
# Avg_Open_To_Buy             8.264056e+07
# Total_Trans_Amt             1.154049e+07
# Total_Trans_Ct              5.509616e+02
# Avg_Utilization_Ratio       7.600579e-02
# dtype: float64

# %% [markdown]
# ### Visualizations

# %% [markdown]
# ### Histogram for customer age distribution

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Customer_Age'], bins=20, color='skyblue', edgecolor='black')
plt.title("Customer Age Distribution")
plt.xlabel("Customer Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Box Plot for age distribution by gender

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='Customer_Age', data=df)
plt.title("Customer Age Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Customer Age")
plt.show()

# %% [markdown]
# ### Scatter Plot: Customer Age Distribution by Attrition

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Attrition_Flag', y='Customer_Age', data=df)
plt.title("Customer Age Distribution by Attrition")
plt.xlabel("Attrition Flag")
plt.ylabel("Customer Age")
plt.show()

# %% [markdown]
# ### Pie chart for gender distribution

# %%
plt.figure(figsize=(6, 6))
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Bar Graph for Income Category Distribution by Gender

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Income_Category', y='Customer_Age', hue='Gender', data=df)
plt.title("Income Category Distribution by Gender")
plt.xlabel("Income Category")
plt.ylabel("Customer Age")
plt.xticks(rotation=45)
plt.legend(title="Gender", loc="upper right")
plt.show()

# %% [markdown]
# ### Barchart for Average Transaction Amount by Education Level

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Education_Level', y='Total_Trans_Amt', data=df)
plt.title("Average Transaction Amount by Education Level")
plt.xticks(rotation=45)
plt.ylabel("Average Transaction Amount")
plt.show()

# %% [markdown]
# ### Graph for attrition by education level

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Education_Level', hue='Attrition_Flag', data=df)
plt.title("Attrition by Education Level")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Bar Graph for average utilization ratio by education level

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Education_Level', y='Avg_Utilization_Ratio', data=df)
plt.title("Average Utilization Ratio by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Average Utilization Ratio")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Distribution of Education Level

# %%
Education = df['Education_Level'].value_counts().sort_values()
plt.figure(figsize=(10,5))  
plt.bar(Education.index,Education)
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Distribution of Education Level')
plt.show()

# %% [markdown]
# ### Pie chart for marital status Distribution

# %%
plt.figure(figsize=(6, 6))
df['Marital_Status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Marital status Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Marital status and Income Category

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Marital_Status', hue='Income_Category', data=df)
plt.title("Marital Status vs. Income Category")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Horizonatal Bar Chart for Income Category Distribution

# %%
plt.figure(figsize=(8, 6))
income_category_counts = df['Income_Category'].value_counts()
sns.barplot(x=income_category_counts, y=income_category_counts.index, orient='h')
plt.title("Income Category Distribution")
plt.xlabel("Count")
plt.ylabel("Income Category")
plt.show()

# %% [markdown]
# ###  Bar chart for income category and average utilization ratio

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Income_Category', y='Avg_Utilization_Ratio', data=df)
plt.title("Income Category and Average Utilization Ratio")
plt.xlabel("Income Category")
plt.xticks(rotation=45)
plt.ylabel("Average Utilization Ratio")
plt.show()

# %% [markdown]
# ### Boxplot for Income category and credit card limit

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Income_Category', y='Credit_Limit', data=df)
plt.title("Income Category vs. Credit Limit")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Bar Plot for Total Transaction Amount by Income Category

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Income_Category', y='Total_Trans_Amt', data=df)
plt.title("Total Transaction Amount by Income Category")
plt.xlabel("Income Category")
plt.ylabel("Total Transaction Amount")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
correlation_matrix = df.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                           CLIENTNUM  Customer_Age  Months_on_book  \
# CLIENTNUM                  1.000000      0.007613        0.134588
# Customer_Age               0.007613      1.000000        0.788912
# Months_on_book             0.134588      0.788912        1.000000
# Total_Relationship_Count   0.006907     -0.010931       -0.009203
# Months_Inactive_12_mon     0.005729      0.054361        0.074164
# Credit_Limit               0.005708      0.002476        0.007507
# Total_Revolving_Bal        0.000825      0.014780        0.008623
# Avg_Open_To_Buy            0.005633      0.001151        0.006732
# Total_Trans_Amt           -0.019692     -0.046446       -0.038591
# Total_Trans_Ct            -0.002961     -0.067097       -0.049819
# Avg_Utilization_Ratio      0.000266      0.007114       -0.007541
#
#                           Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM                                 0.006907                0.005729
# ...

# %% [markdown]
# ### Correlation matrix using heatmap

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Histogram For Average Utilization Ratio Distribution

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Avg_Utilization_Ratio'], bins=20, kde=True)
plt.title("Average Utilization Ratio Distribution")
plt.xlabel("Average Utilization Ratio")
plt.show()

# %% [markdown]
# ### Line Chart for Total Transaction Count Trend by Months on Book

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Months_on_book', y='Total_Trans_Ct', data=df)
plt.title("Total Transaction Count Trend by Months on Book")
plt.xlabel("Months on Book")
plt.ylabel("Total Transaction Count")
plt.show()

# %% [markdown]
# ### Line Chart for Average Utilization Ratio Trend by Months on Book

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Months_on_book', y='Avg_Utilization_Ratio', data=df)
plt.title("Average Utilization Ratio Trend by Months on Book")
plt.xlabel("Months on Book")
plt.ylabel("Average Utilization Ratio")
plt.show()

# %% [markdown]
# ### Line Chart for Average Utilization Ratio Trend by Credit Limit

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Credit_Limit', y='Avg_Utilization_Ratio', data=df)
plt.title("Average Utilization Ratio Trend by Credit Limit")
plt.xlabel("Credit Limit")
plt.ylabel("Average Utilization Ratio")
plt.show()
